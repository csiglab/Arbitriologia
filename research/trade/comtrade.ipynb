# %% [markdown]
# ## Breaviarium
#
# - What problems does the COMTRADE data has?

# %%
# Install a pip comtradeapicall package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install --upgrade comtradeapicall
# Out:
# Collecting comtradeapicall
#   Downloading comtradeapicall-1.2.1-py3-none-any.whl.metadata (19 kB)
# Downloading comtradeapicall-1.2.1-py3-none-any.whl (19 kB)
# Installing collected packages: comtradeapicall
# Successfully installed comtradeapicall-1.2.1

# %%
import pandas
import requests
import comtradeapicall

# %%
subscription_key = '<KEY>' # comtrade api subscription key (from comtradedeveloper.un.org)
directory = '/home/dbremont/Code/arbitrista-labs/data'  # output directory for downloaded files
# proxy_url = '<PROXY URL>'  # optional if you need proxy url

# %%
#set some variables
from datetime import date
from datetime import timedelta
today = date.today()
yesterday = today - timedelta(days=1)
lastweek = today - timedelta(days=7)

# %%
# Call preview final data API to a data frame, max to 500 records, no subscription key required
# This example: Australia imports of commodity code 91 in classic mode in May 2022

# %%
mydf = comtradeapicall.previewFinalData(typeCode='C', freqCode='M', clCode='HS', period='202205',
                                        reporterCode='36', cmdCode='91', flowCode='M', partnerCode=None,
                                        partner2Code=None,
                                        customsCode=None, motCode=None, maxRecords=500, format_output='JSON',
                                        aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)

# %%
mydf
# Out:
#    typeCode freqCode  refPeriodId  refYear  refMonth  period  reporterCode  \
# 0         C        M     20220501     2022         5  202205            36
# 1         C        M     20220501     2022         5  202205            36
# 2         C        M     20220501     2022         5  202205            36
# 3         C        M     20220501     2022         5  202205            36
# 4         C        M     20220501     2022         5  202205            36
# 5         C        M     20220501     2022         5  202205            36
# 6         C        M     20220501     2022         5  202205            36
# 7         C        M     20220501     2022         5  202205            36
# 8         C        M     20220501     2022         5  202205            36
# 9         C        M     20220501     2022         5  202205            36
# 10        C        M     20220501     2022         5  202205            36
# 11        C        M     20220501     2022         5  202205            36
# 12        C        M     20220501     2022         5  202205            36
# 13        C        M     20220501     2022         5  202205            36
# 14        C        M     20220501     2022         5  202205            36
# 15        C        M     20220501     2022         5  202205            36
# 16        C        M     20220501     2022         5  202205            36
# 17        C        M     20220501     2022         5  202205            36
# 18        C        M     20220501     2022         5  202205            36
# 19        C        M     20220501     2022         5  202205            36
# 20        C        M     20220501     2022         5  202205            36
# 21        C        M     20220501     2022         5  202205            36
# 22        C        M     20220501     2022         5  202205            36
# 23        C        M     20220501     2022         5  202205            36
# 24        C        M     20220501     2022         5  202205            36
# 25        C        M     20220501     2022         5  202205            36
# 26        C        M     20220501     2022         5  202205            36
# 27        C        M     20220501     2022         5  202205            36
# 28        C        M     20220501     2022         5  202205            36
# 29        C        M     20220501     2022         5  202205            36
# 30        C        M     20220501     2022         5  202205            36
# 31        C        M     20220501     2022         5  202205            36
# 32        C        M     20220501     2022         5  202205            36
# 33        C        M     20220501     2022         5  202205            36
# 34        C        M     20220501     2022         5  202205            36
# 35        C        M     20220501     2022         5  202205            36
# 36        C        M     20220501     2022         5  202205            36
# 37        C        M     20220501     2022         5  202205            36
# 38        C        M     20220501     2022         5  202205            36
# 39        C        M     20220501     2022         5  202205            36
# 40        C        M     20220501     2022         5  202205            36
# 41        C        M     20220501     2022         5  202205            36
# 42        C        M     20220501     2022         5  202205            36
# 43        C        M     20220501     2022         5  202205            36
# 44        C        M     20220501     2022         5  202205            36
# 45        C        M     20220501     2022         5  202205            36
# 46        C        M     20220501     2022         5  202205            36
# 47        C        M     20220501     2022         5  202205            36
# 48        C        M     20220501     2022         5  202205            36
# 49        C        M     20220501     2022         5  202205            36
# 50        C        M     20220501     2022         5  202205            36
# 51        C        M     20220501     2022         5  202205            36
#
#    reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated grossWgt  \
# 0          AUS    Australia        M  ...    0.0              False      0.0
# 1          AUS    Australia        M  ...    0.0              False      0.0
# 2          AUS    Australia        M  ...    0.0              False      0.0
# 3          AUS    Australia        M  ...    0.0               True      0.0
# 4          AUS    Australia        M  ...    0.0              False      0.0
# 5          AUS    Australia        M  ...    0.0              False      0.0
# 6          AUS    Australia        M  ...    0.0              False      0.0
# 7          AUS    Australia        M  ...    0.0               True      0.0
# 8          AUS    Australia        M  ...    0.0              False      0.0
# 9          AUS    Australia        M  ...    0.0               True      0.0
# 10         AUS    Australia        M  ...    0.0               True      0.0
# 11         AUS    Australia        M  ...    0.0              False      0.0
# 12         AUS    Australia        M  ...    0.0              False      0.0
# 13         AUS    Australia        M  ...    0.0              False      0.0
# 14         AUS    Australia        M  ...    0.0               True      0.0
# 15         AUS    Australia        M  ...    0.0              False      0.0
# 16         AUS    Australia        M  ...    0.0              False      0.0
# 17         AUS    Australia        M  ...    0.0               True      0.0
# 18         AUS    Australia        M  ...    0.0              False      0.0
# 19         AUS    Australia        M  ...    0.0              False      0.0
# 20         AUS    Australia        M  ...    0.0               True      0.0
# 21         AUS    Australia        M  ...    0.0               True      0.0
# 22         AUS    Australia        M  ...    0.0               True      0.0
# 23         AUS    Australia        M  ...    0.0              False      0.0
# 24         AUS    Australia        M  ...    0.0              False      0.0
# 25         AUS    Australia        M  ...    0.0              False      0.0
# 26         AUS    Australia        M  ...    0.0              False      0.0
# 27         AUS    Australia        M  ...    0.0              False      0.0
# 28         AUS    Australia        M  ...    0.0               True      0.0
# 29         AUS    Australia        M  ...    0.0              False      0.0
# 30         AUS    Australia        M  ...    0.0               True      0.0
# 31         AUS    Australia        M  ...    0.0              False      0.0
# 32         AUS    Australia        M  ...    0.0               True      0.0
# 33         AUS    Australia        M  ...    0.0              False      0.0
# 34         AUS    Australia        M  ...    0.0              False      0.0
# 35         AUS    Australia        M  ...    0.0              False      0.0
# 36         AUS    Australia        M  ...    0.0              False      0.0
# 37         AUS    Australia        M  ...    0.0              False      0.0
# 38         AUS    Australia        M  ...    0.0               True      0.0
# 39         AUS    Australia        M  ...    0.0              False      0.0
# 40         AUS    Australia        M  ...    0.0               True      0.0
# 41         AUS    Australia        M  ...    0.0              False      0.0
# 42         AUS    Australia        M  ...    0.0              False      0.0
# 43         AUS    Australia        M  ...    0.0              False      0.0
# 44         AUS    Australia        M  ...    0.0              False      0.0
# 45         AUS    Australia        M  ...    0.0              False      0.0
# 46         AUS    Australia        M  ...    0.0              False      0.0
# 47         AUS    Australia        M  ...    0.0              False      0.0
# 48         AUS    Australia        M  ...    0.0               True      0.0
# 49         AUS    Australia        M  ...    0.0               True      0.0
# 50         AUS    Australia        M  ...    0.0               True      0.0
# 51         AUS    Australia        M  ...    0.0              False      0.0
#
#    isGrossWgtEstimated      cifvalue      fobvalue  primaryValue  \
# 0                False  6.735064e+07  6.642209e+07  6.735064e+07
# 1                False  8.208810e+02  7.800080e+02  8.208810e+02
# 2                False  2.605931e+05  2.599554e+05  2.605931e+05
# 3                False  2.668635e+04  2.544649e+04  2.668635e+04
# 4                False  7.410397e+03  7.027445e+03  7.410397e+03
# 24                    0      False         True
# 25                    0      False         True
# 26                    0      False         True
# 27                    0      False         True
# 28                    4      False         True
# 29                    0      False         True
# 30                    4      False         True
# 31                    0      False         True
# 32                    4      False         True
# 33                    0      False         True
# 34                    0      False         True
# 35                    0      False         True
# 36                    0      False         True
# 37                    0      False         True
# 38                    4      False         True
# 39                    0      False         True
# 40                    4      False         True
# 41                    0      False         True
# 42                    0      False         True
# 43                    0      False         True
# 44                    0      False         True
# 45                    0      False         True
# 46                    0      False         True
# 47                    0      False         True
# 48                    4      False         True
# 49                    4      False         True
# 50                    4      False         True
# 51                    0      False         True
#
# [52 rows x 47 columns]

# %%
## Use of subscription key to call final data API to a data frame, max to 2500 records
mydf = comtradeapicall.getFinalData(subscription_key, typeCode='C', freqCode='M', clCode='HS', period='202205',
                                    reporterCode='36', cmdCode='91,90', flowCode='M', partnerCode=None,
                                    partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=2500, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)

# %%
mydf
# Out:
#     typeCode freqCode  refPeriodId  refYear  refMonth  period  reporterCode  \
# 0          C        M     20220501     2022         5  202205            36
# 1          C        M     20220501     2022         5  202205            36
# 2          C        M     20220501     2022         5  202205            36
# 3          C        M     20220501     2022         5  202205            36
# 4          C        M     20220501     2022         5  202205            36
# ..       ...      ...          ...      ...       ...     ...           ...
# 145        C        M     20220501     2022         5  202205            36
# 146        C        M     20220501     2022         5  202205            36
# 147        C        M     20220501     2022         5  202205            36
# 148        C        M     20220501     2022         5  202205            36
# 149        C        M     20220501     2022         5  202205            36
#
#     reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated grossWgt  \
# 0           AUS    Australia        M  ...    0.0              False      0.0
# 1           AUS    Australia        M  ...    0.0              False      0.0
# 2           AUS    Australia        M  ...    0.0               True      0.0
# 3           AUS    Australia        M  ...    0.0               True      0.0
# 4           AUS    Australia        M  ...    0.0               True      0.0
# ..          ...          ...      ...  ...    ...                ...      ...
# 145         AUS    Australia        M  ...    0.0              False      0.0
# 146         AUS    Australia        M  ...    0.0               True      0.0
# 147         AUS    Australia        M  ...    0.0               True      0.0
# 148         AUS    Australia        M  ...    0.0               True      0.0
# 149         AUS    Australia        M  ...    0.0              False      0.0
#
#     isGrossWgtEstimated      cifvalue      fobvalue  primaryValue  \
# 0                 False  8.388227e+08  8.012504e+08  8.388227e+08
# 1                 False  1.852201e+03  1.726534e+03  1.852201e+03
# 2                 False  3.695805e+03  3.224809e+03  3.695805e+03
# 3                 False  1.190824e+05  1.114879e+05  1.190824e+05
# 4                 False  6.946143e+06  6.808902e+06  6.946143e+06
# ..                  ...           ...           ...           ...
# 145               False  5.319135e+07  5.285762e+07  5.319135e+07
# 146               False  6.276322e+05  6.088987e+05  6.276322e+05
# 147               False  2.781753e+03  2.535053e+03  2.781753e+03
# 148               False  3.094262e+05  3.033966e+05  3.094262e+05
# 149               False  1.030765e+06  1.005766e+06  1.030765e+06
#
#     legacyEstimationFlag isReported  isAggregate
# 0                      0      False         True
# 1                      0      False         True
# 2                      4      False         True
# 3                      4      False         True
# 4                      4      False         True
# ..                   ...        ...          ...
# 145                    0      False         True
# 146                    4      False         True
# 147                    4      False         True
# 148                    4      False         True
# 149                    0      False         True
#
# [150 rows x 47 columns]

# %% [markdown]
# ## References

# %% [markdown]
# - [example calling functions - notebook.ipynb](https://github.com/uncomtrade/comtradeapicall/blob/main/tests/example%20calling%20functions%20-%20notebook.ipynb)
